# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.document_loaders import TextLoader,DirectoryLoader
from langchain_chroma import Chroma
from langchain_text_splitters import TextSplitter

# %%
load_dotenv()
GEMINI_API_KEY = os.environ.get('GEMINI_API_KEY')

# %%
def load_docs(path: str) -> list :
    """
    Load the documents in the given path 
    """
    if not os.path.exists(path) :
        raise FileNotFoundError("No such directory exist ....")
    
    loader = DirectoryLoader(
        path=path,
        loader_cls=TextLoader,
        show_progress=True,
        glob="*.txt",
        loader_kwargs={"encoding": "utf-8"}
    )

    documents = loader.load()

    if len(documents) == 0:
        raise FileNotFoundError("There is no .txt files in the given directory...")
    
    for doc in documents:
        print("="*50)
        print("Source :",doc.metadata['source'])
        print("Context Length :",len(doc.page_content))
    return documents

# %%
path = "../docs"
load_docs(path=path)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 903.40it/s]
# ...
# Source : ..\docs\Google.txt
# Context Length : 232201
# ...
# Source : ..\docs\Microsoft.txt
# Context Length : 201014
# ...
# Source : ..\docs\Nvidia.txt
# Context Length : 148417
# ...
# Source : ..\docs\SpaceX.txt
# Context Length : 206132
# ...
# Source : ..\docs\Tesla.txt
# Context Length : 299196
# ...
